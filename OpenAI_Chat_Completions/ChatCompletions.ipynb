# %% [markdown]
# ## Calling our OpenAI Model from Microsoft Foundry

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Collecting azure-ai-projects==2.0.0b2
#   Downloading azure_ai_projects-2.0.0b2-py3-none-any.whl.metadata (63 kB)
# Collecting openai==1.109.1
#   Downloading openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: python-dotenv in e:\anmol\python\anaconda_installation\install\lib\site-packages (0.21.0)
# Collecting azure-identity
#   Downloading azure_identity-1.25.3-py3-none-any.whl.metadata (91 kB)
# Collecting isodate>=0.6.1 (from azure-ai-projects==2.0.0b2)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.35.0 (from azure-ai-projects==2.0.0b2)
#   Downloading azure_core-1.39.0-py3-none-any.whl.metadata (48 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from azure-ai-projects==2.0.0b2) (4.11.0)
# Collecting azure-storage-blob>=12.15.0 (from azure-ai-projects==2.0.0b2)
#   Downloading azure_storage_blob-12.28.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (0.27.0)
# Collecting jiter<1,>=0.4.0 (from openai==1.109.1)
#   Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic<3,>=1.9.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (2.8.2)
# Requirement already satisfied: sniffio in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (1.3.0)
# Requirement already satisfied: tqdm>4 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from openai==1.109.1) (4.66.5)
# Requirement already satisfied: cryptography>=2.5 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from azure-identity) (43.0.0)
# Collecting msal>=1.35.1 (from azure-identity)
#   Downloading msal-1.35.1-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity)
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: idna>=2.8 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.7)
# Requirement already satisfied: requests>=2.21.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.3)
# Requirement already satisfied: cffi>=1.12 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from cryptography>=2.5->azure-identity) (1.17.1)
# Requirement already satisfied: certifi in e:\anmol\python\anaconda_installation\install\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in e:\anmol\python\anaconda_installation\install\lib\site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.14.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.35.1->azure-identity) (2.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.20.1)
# Requirement already satisfied: colorama in e:\anmol\python\anaconda_installation\install\lib\site-packages (from tqdm>4->openai==1.109.1) (0.4.6)
# Requirement already satisfied: pycparser in e:\anmol\python\anaconda_installation\install\lib\site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anmol\python\anaconda_installation\install\lib\site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.2.3)
# Downloading azure_ai_projects-2.0.0b2-py3-none-any.whl (234 kB)
# Downloading openai-1.109.1-py3-none-any.whl (948 kB)
#    ---------------------------------------- 0.0/948.6 kB ? eta -:--:--
#    --------------------------------------- 948.6/948.6 kB 10.9 MB/s eta 0:00:00
# Downloading azure_identity-1.25.3-py3-none-any.whl (192 kB)
# Downloading azure_core-1.39.0-py3-none-any.whl (218 kB)
# Downloading azure_storage_blob-12.28.0-py3-none-any.whl (431 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading jiter-0.13.0-cp312-cp312-win_amd64.whl (205 kB)
# Downloading msal-1.35.1-py3-none-any.whl (119 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Installing collected packages: jiter, isodate, azure-core, openai, azure-storage-blob, msal, azure-ai-projects, msal-extensions, azure-identity
# Successfully installed azure-ai-projects-2.0.0b2 azure-core-1.39.0 azure-identity-1.25.3 azure-storage-blob-12.28.0 isodate-0.7.2 jiter-0.13.0 msal-1.35.1 msal-extensions-1.3.1 openai-1.109.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Setting up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting up the AI Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %% [markdown]
# ### Setting up the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

# %% [markdown]
# ### Sending a Request to the OpenAI Model

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
# Out:
# Response output: “Microsoft Foundry” usually refers to **Azure AI Foundry**, Microsoft’s platform for building, customizing, and deploying AI applications.
#
# In simple terms, it’s a **development hub for AI** that brings together models, tools, and infrastructure so teams can create AI-powered apps faster.
#
# Key ideas:
#
# • **Model access** – You can use many AI models in one place (OpenAI models like GPT, Microsoft models, and some open‑source models).
# • **Model customization** – Tools for fine‑tuning or grounding models with your own data.
# • **Evaluation & safety** – Built‑in testing, monitoring, and safety controls for AI systems.
# • **App development tools** – SDKs, APIs, and integrations to build chatbots, copilots, and AI workflows.
# • **Enterprise deployment** – Runs on Azure with security, scaling, and governance.
#
# Typical uses:
# - Building company chatbots using internal documents
# - Creating AI copilots for apps or employees
# - Automating workflows with LLMs
# - Experimenting with different AI models and comparing results
#
# Think of **Azure AI Foundry as a “workshop” for AI**: models + tools + infrastructure in one place so developers and companies can build production AI systems.
#
# If you want, I can also explain:
# - how it’s different from **Azure OpenAI**
# - how it compares to **AWS Bedrock** or **Google Vertex AI**.
